# %%
#labraries
import pandas as pd # handle to analize the tublar data
import numpy as np
import matplotlib.pyplot as plt #matplotlib.pyplot is a state-based interface to matplotlib. It use for graph.
import seaborn as sns # make better looking charts and graphs.

#create and collect ur dataset
data = {'Fruit': ['Apple', 'Banana', 'Orange', 'Apple", "Banana', 'Orange', 'Apple', 'Banana'],
 'Price_per_kg': [120, 60, 80, 125, 55, 75, 130, 65], 'Quantity_Sold': [30, 50, 40, 35, 60, 42, 25, 55], 'Day':
 ['Mon', 'Mon', 'Mon', 'Tue', 'Tue', 'Tue', 'Wed', 'Wed']}
df = pd.DataFrame(data)

 #cleaning the data
print(df.isnull.sum()) # to find the missing value
#fix the datasets
df.[]
